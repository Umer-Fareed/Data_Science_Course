# %%
import pandas as pd

# File path
file_path = r'D:\STUDY MATERIAL\Python programing\pythonBasics\chapter_3_assets\1_intro\movies.csv'

# Load the CSV file into a DataFrame
df = pd.read_csv(file_path)
df.head(2)
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
#
#   currency language
# 0      INR  Bengali
# 1      USD  English

# %%
df[2:7]
# Out:
#                       title   industry  release_year  imdb_rating  \
# 2     Thor: The Dark World   Hollywood          2013          6.8
# 3           Thor: Ragnarok   Hollywood          2017          7.9
# 4   Thor: Love and Thunder   Hollywood          2022          6.8
# 5  The Shawshank Redemption  Hollywood          1994          9.3
# 6              Interstellar  Hollywood          2014          8.6
#
#                       studio  budget  revenue      unit currency language
# 2             Marvel Studios   165.0    644.8  Millions      USD  English
# 3             Marvel Studios   180.0    854.0  Millions      USD  English
# 4             Marvel Studios   250.0    670.0  Millions      USD  English
# 5  Castle Rock Entertainment    25.0     73.3  Millions      USD  English
# 6      Warner Bros. Pictures   165.0    701.8  Millions      USD  English

# %%
df.shape
# Out:
# (37, 10)

# %%
df["imdb_rating"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('imdb_rating', 3)
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df["imdb_rating",3]
#
# ...

# %%
dir(df.imdb_rating)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__column_consortium_standard__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %%
df.imdb_rating.min(),df.imdb_rating.max(),df.imdb_rating.mean()
# Out:
# (1.9, 9.3, 7.919444444444445)

# %%
df_b=df[df.industry == "Bollywood"]
df_h=df[df.industry == "Hollywood"]

# %%
df_b.imdb_rating.min(),df_b.imdb_rating.max()
# Out:
# (1.9, 8.4)

# %%
df_h.imdb_rating.min(),df_h.imdb_rating.max()
# Out:
# (6.8, 9.3)
