# %%
import pandas as pd
import numpy as np

# %%
#to upload csv file to our jupyter notebook
df = pd.read_csv("income.csv", names=['name','income'],skiprows=[0])
df
# Out:
#         name    income
# 0        Rob      5000
# 1      Rafiq      6000
# 2       Nina      4000
# 3      Sofia      7500
# 4      Mohan      8000
# 5        Tao      7000
# 6  Elon Musk  10000000

# %%
#to check the summary of the data
df['income'].describe()
# Out:
# count    6.000000e+00
# mean     1.671667e+06
# std      4.080034e+06
# min      4.000000e+03
# 25%      5.250000e+03
# 50%      6.500000e+03
# 75%      7.750000e+03
# max      1.000000e+07
# Name: income, dtype: float64

# %%
#to check the velue at 75th position of data 
df.income.quantile(0.75 ,interpolation = "lower")
# Out:
# 7500

# %%
#to check value at 25th percent of data
df.income.quantile(0.25 ,interpolation = "higher")
# Out:
# 6000

# %%
#to check velue at 100 position in data 
df.income.quantile(1)
# Out:
# 10000000.0

# %%
#to store the velue that is are more the 99 percent of the data 
percentile_99 = df.income.quantile(.99)
percentile_99
# Out:
# 9400479.999999994

# %%
#to check which velue is more then 99 percent of the data 
df[df.income>percentile_99]
# Out:
#         name    income
# 6  Elon Musk  10000000

# %%
#to remove the velue that is more then 99 precent of data and store in a veriable
df_no_outlier = df[df.income<=percentile_99]
df_no_outlier
# Out:
#     name  income
# 0    Rob    5000
# 1  Rafiq    6000
# 2   Nina    4000
# 3  Sofia    7500
# 4  Mohan    8000
# 5    Tao    7000

# %%
#filling a missing velue
df
# Out:
#         name    income
# 0        Rob      5000
# 1      Rafiq      6000
# 2       Nina      4000
# 3      Sofia      7500
# 4      Mohan      8000
# 5        Tao      7000
# 6  Elon Musk  10000000

# %%
#make the velue of sofia null by using numpy funciton NaN
df['income'][3]=np.NaN

# %%
df
# Out:
#         name      income
# 0        Rob      5000.0
# 1      Rafiq      6000.0
# 2       Nina      4000.0
# 3      Sofia         NaN
# 4      Mohan      8000.0
# 5        Tao      7000.0
# 6  Elon Musk  10000000.0

# %%
#check the mean of a column in a data frame using mean() functino of numpy
df.income.mean()
# Out:
# 1671666.6666666667

# %%
#filling null velue with the mean of the column
df.fillna(df.income.mean())
# Out:
#         name        income
# 0        Rob  5.000000e+03
# 1      Rafiq  6.000000e+03
# 2       Nina  4.000000e+03
# 3      Sofia  1.671667e+06
# 4      Mohan  8.000000e+03
# 5        Tao  7.000000e+03
# 6  Elon Musk  1.000000e+07

# %%
#now use median for filling the null value 
df.fillna(df.income.median())
# Out:
#         name      income
# 0        Rob      5000.0
# 1      Rafiq      6000.0
# 2       Nina      4000.0
# 3      Sofia      6500.0
# 4      Mohan      8000.0
# 5        Tao      7000.0
# 6  Elon Musk  10000000.0

# %%
#read new csv file of data 
df_new = pd.read_csv("AB_NYC_2019.csv")
#to check first  5 rows of the data 
df_new.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
#to discribe the price column in the data 
df_new['price'].describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
#to check the median of price column in the data 
df_new['price'].median()
# Out:
# 106.0

# %%
#to check the velue at 25th position in the data 
df_new['price'].quantile(.25)
# Out:
# 69.0

# %%
# to check the velue in price column at 75th position in data 
df_new['price'].quantile(.75)
# Out:
# 175.0

# %%
#to check the velue at 99th position in the data 
df2=df_new['price'].quantile(.99)
df2
# Out:
# 799.0

# %%
#to check the velues that are more then 99 percent of the data 
df_new[df_new.price>df2]
# Out:
#              id                                               name    host_id  \
# 85        19601                perfect for a family or small group      74303
# 496      174966              Luxury 2Bed/2.5Bath Central Park View     836168
# 662      250801                 Heart & Soul of Greenwich Village     1314834
# 762      273190          6 Bedroom Landmark West Village Townhouse     605463
# 780      279857  #1 Yellow Block BnB/see at Net Flix Show Stay ...    1420300
# ...         ...                                                ...        ...
# 48304  36189195      Next to Times Square/Javits/MSG! Amazing 1BR!  270214015
# 48305  36189257             2BR Near Museum Mile! Upper East Side!  272166348
# 48523  36308562  Tasteful & Trendy Brooklyn Brownstone, near Train  217732163
# 48535  36311055     Stunning & Stylish Brooklyn Luxury, near Train  245712163
# 48839  36452721  Massage Spa. Stay overnight. Authors Artist dr...  274079964
#
# ...

# %%
#to create a new data frame that hold the velues that are less then the 100th value 
df_new2= df_new[df_new.price <= df2]
df_new2.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
#to describe the new data frame 
df_new2.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.842100e+04  4.842100e+04  48421.000000  48421.000000  48421.000000
# mean   1.901641e+07  6.757814e+07     40.728906    -73.951928    137.543917
# std    1.097331e+07  7.854980e+07      0.054619      0.046163    103.789003
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.476774e+06  7.825587e+06     40.689960    -73.982840     69.000000
# 50%    1.967610e+07  3.083601e+07     40.722900    -73.955480    105.000000
# 75%    2.913231e+07  1.074344e+08     40.763150    -73.935950    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990    799.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48421.000000       48421.000000       38593.000000
# mean         6.979596          23.415130           1.376141
# std         20.291590          44.699315           1.682898
# ...

# %%
# to check the head of new data farame 
df_new2.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# to check the 75th velue of new data frame 
df_new2.price.quantile(0.75)
# Out:
# 175.0

# %%
#playing with quantile 
df_new2.price.quantile(0.99,interpolation = "higher")
# Out:
# 550

# %%
#playing with quantile 
df_new2.price.quantile(1 , interpolation = "lower")
# Out:
# 799

# %%
# check the summary of new data frame
df_new2.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.842100e+04  4.842100e+04  48421.000000  48421.000000  48421.000000
# mean   1.901641e+07  6.757814e+07     40.728906    -73.951928    137.543917
# std    1.097331e+07  7.854980e+07      0.054619      0.046163    103.789003
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.476774e+06  7.825587e+06     40.689960    -73.982840     69.000000
# 50%    1.967610e+07  3.083601e+07     40.722900    -73.955480    105.000000
# 75%    2.913231e+07  1.074344e+08     40.763150    -73.935950    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990    799.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48421.000000       48421.000000       38593.000000
# mean         6.979596          23.415130           1.376141
# std         20.291590          44.699315           1.682898
# ...

# %%
# to check how many Na values in our data farame in each column
nan_counts = df_new2.isna().sum()
nan_counts
# Out:
# id                                   0
# name                                16
# host_id                              0
# host_name                           21
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       9828
# reviews_per_month                 9828
# calculated_host_listings_count       0
# availability_365                     0
# dtype: int64

# %%
# to check the length of the data frame 
len(df_new2)
# Out:
# 48421

# %%
# to check hte number of column in our data frame 
len(df_new2.columns)
# Out:
# 16

# %%
# to fill the NaN value with the median of that column 
df_new2.fillna(df_new2.reviews_per_month.median())
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
# check the head ()
df_new2.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...
